# %% [markdown]
# # 1. pandas and other libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # 2. load dataset

# %%
df1=pd.read_excel("C:/Users/Asus/Desktop/NEW START/practice data.xlsx",sheet_name="dataset")
df2=pd.read_excel("C:/Users/Asus/Desktop/NEW START/practice data.xlsx",sheet_name="customer table")
df3=pd.read_excel("C:/Users/Asus/Desktop/NEW START/practice data.xlsx",sheet_name="product table")

# %% [markdown]
# # 3 . Show first 5 rows

# %%
df1.head(5)
# Out:
#    OrderID  OrderDate    month CustomerID CustomerName Region ProductID  \
# 0     1001 1900-01-03  January       2024  Amit Sharma  North      P101
# 1     1002 2024-01-04  January       C002   Neha Verma  South      P102
# 2     1003 2024-01-05  January       C003  Rohit Kumar   East      P201
# 3     1004 2024-01-06  January       C004  Pooja Singh   West      P202
# 4     1005 2024-01-07  January       C005  Vikram Rana  North      P103
#
#   ProductName     Category  Sales  Quantity
# 0      Laptop  Electronics  55000         1
# 1      Mobile  Electronics  18000         2
# 2       Table    Furniture   7000         1
# 3       Chair    Furniture   3500         3
# 4  Headphones  Electronics   2500         2

# %%
df2.head(2)
# Out:
#   CustomerID CustomerName    City
# 0       C001  Amit Sharma   Delhi
# 1       C002   Neha Verma  Mumbai

# %%
df3.head(2)
# Out:
#   ProductID ProductName     Category  UnitPrice
# 0      P101      Laptop  Electronics      55000
# 1      P102      Mobile  Electronics      18000

# %% [markdown]
# # 4 . Show last 5 rows

# %%
df1.tail(5)
# Out:
#     OrderID  OrderDate     month CustomerID  CustomerName Region ProductID  \
# 45     1046 2024-02-17  February       C006     Alok Jain  South      P202
# 46     1047 2024-02-18  February       C007  Sakshi Mehta   East      P102
# 47     1048 2024-02-19  February       C008   Harsh Gupta   West      P103
# 48     1049 2024-02-20  February       C001   Amit Sharma  North      P201
# 49     1050 2024-02-21  February       C002    Neha Verma  South      P203
#
#    ProductName     Category  Sales  Quantity
# 45       Chair    Furniture   3500         2
# 46      Mobile  Electronics  18500         1
# 47  Headphones  Electronics   2900         3
# 48       Table    Furniture   7400         1
# 49         Bed    Furniture  16100         1

# %%
sheet1=df2.merge(df1, on="CustomerName", how ="left")

# %%
sheet1.head(2)
# Out:
#   CustomerID_x CustomerName   City  OrderID  OrderDate    month CustomerID_y  \
# 0         C001  Amit Sharma  Delhi     1001 1900-01-03  January         2024
# 1         C001  Amit Sharma  Delhi     1009 2024-01-11  January         C001
#
#   Region ProductID ProductName     Category  Sales  Quantity
# 0  North      P101      Laptop  Electronics  55000         1
# 1  North      P202       Chair    Furniture   3600         2

# %%
sheet11=sheet1[["OrderID","CustomerID_x","OrderDate","CustomerName","Region","City","ProductID","ProductName","Category","Sales","Quantity"]]

# %%
sheet11.head(2)
# Out:
#    OrderID CustomerID_x  OrderDate CustomerName Region   City ProductID  \
# 0     1001         C001 1900-01-03  Amit Sharma  North  Delhi      P101
# 1     1009         C001 2024-01-11  Amit Sharma  North  Delhi      P202
#
#   ProductName     Category  Sales  Quantity
# 0      Laptop  Electronics  55000         1
# 1       Chair    Furniture   3600         2

# %%
df33 = df3[["ProductID", "UnitPrice"]]

# %%
df33
# Out:
#   ProductID  UnitPrice
# 0      P101      55000
# 1      P102      18000
# 2      P103       2400
# 3      P201       6500
# 4      P202       1500
# 5      P203      14500

# %%
finaldf=df33.merge(sheet1,on="ProductID", how = "left")

# %%
finaldf.head(2)
# Out:
#   ProductID  UnitPrice CustomerID_x CustomerName    City  OrderID  OrderDate  \
# 0      P101      55000         C001  Amit Sharma   Delhi     1001 1900-01-03
# 1      P101      55000         C002   Neha Verma  Mumbai     1018 2024-01-20
#
#      month CustomerID_y Region ProductName     Category  Sales  Quantity
# 0  January         2024  North      Laptop  Electronics  55000         1
# 1  January         C002  South      Laptop  Electronics  62000         1

# %%
final_df=finaldf[["OrderID","CustomerID_x","OrderDate","CustomerName","Region","City","ProductID","ProductName","Category","Sales","Quantity","UnitPrice"]]

# %%
final_df.head(2)
# Out:
#    OrderID CustomerID_x  OrderDate CustomerName Region    City ProductID  \
# 0     1001         C001 1900-01-03  Amit Sharma  North   Delhi      P101
# 1     1018         C002 2024-01-20   Neha Verma  South  Mumbai      P101
#
#   ProductName     Category  Sales  Quantity  UnitPrice
# 0      Laptop  Electronics  55000         1      55000
# 1      Laptop  Electronics  62000         1      55000

# %% [markdown]
# # 5.  Check shape

# %%
final_df.shape
# Out:
# (50, 12)

# %% [markdown]
# # 6. Column names

# %%
final_df.columns
# Out:
# Index(['OrderID', 'CustomerID_x', 'OrderDate', 'CustomerName', 'Region',
#        'City', 'ProductID', 'ProductName', 'Category', 'Sales', 'Quantity',
#        'UnitPrice'],
#       dtype='object')

# %% [markdown]
# # 7. Dataset info

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       50 non-null     int64
#  1   CustomerID_x  50 non-null     object
#  2   OrderDate     50 non-null     datetime64[ns]
#  3   CustomerName  50 non-null     object
#  4   Region        50 non-null     object
#  5   City          50 non-null     object
#  6   ProductID     50 non-null     object
#  7   ProductName   50 non-null     object
#  8   Category      50 non-null     object
#  9   Sales         50 non-null     int64
#  10  Quantity      50 non-null     int64
#  11  UnitPrice     50 non-null     int64
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 4.8+ KB

# %% [markdown]
# # 8. Summary statistics

# %%
final_df.describe()
# Out:
#           OrderID            OrderDate         Sales   Quantity     UnitPrice
# count    50.00000                   50     50.000000  50.000000     50.000000
# mean   1025.50000  2021-08-04 16:48:00  19204.000000   1.500000  17454.000000
# min    1001.00000  1900-01-03 00:00:00   2500.000000   1.000000   1500.000000
# 25%    1013.25000  2024-01-15 06:00:00   3562.500000   1.000000   2400.000000
# 50%    1025.50000  2024-01-27 12:00:00  15600.000000   1.000000  14500.000000
# 75%    1037.75000  2024-02-08 18:00:00  18950.000000   2.000000  18000.000000
# max    1050.00000  2024-02-21 00:00:00  64000.000000   3.000000  55000.000000
# std      14.57738                  NaN  20389.920579   0.707107  18797.917926

# %% [markdown]
# # 9. Select specific columns

# %%
df1["CustomerName"]
# Out:
# 0      Amit Sharma
# 1       Neha Verma
# 2      Rohit Kumar
# 3      Pooja Singh
# 4      Vikram Rana
# 5        Alok Jain
# 6     Sakshi Mehta
# 7      Harsh Gupta
# 8      Amit Sharma
# 9       Neha Verma
# 10     Rohit Kumar
# 11     Pooja Singh
# 12     Vikram Rana
# 13       Alok Jain
# 14    Sakshi Mehta
# 15     Harsh Gupta
# 16     Amit Sharma
# 17      Neha Verma
# 18     Rohit Kumar
# 19     Pooja Singh
# 20     Vikram Rana
# 21       Alok Jain
# 22    Sakshi Mehta
# 23     Harsh Gupta
# 24     Amit Sharma
# 25      Neha Verma
# 26     Rohit Kumar
# 27     Pooja Singh
# 28     Vikram Rana
# 29       Alok Jain
# 30    Sakshi Mehta
# 31     Harsh Gupta
# 32     Amit Sharma
# 33      Neha Verma
# 34     Rohit Kumar
# 35     Pooja Singh
# 36     Vikram Rana
# 37       Alok Jain
# 38    Sakshi Mehta
# 39     Harsh Gupta
# 40     Amit Sharma
# 41      Neha Verma
# 42     Rohit Kumar
# 43     Pooja Singh
# 44     Vikram Rana
# 45       Alok Jain
# 46    Sakshi Mehta
# ...

# %% [markdown]
# # 10. Select first 10 rows of selected columns

# %%
df1["CustomerName"].head(10)
# Out:
# 0     Amit Sharma
# 1      Neha Verma
# 2     Rohit Kumar
# 3     Pooja Singh
# 4     Vikram Rana
# 5       Alok Jain
# 6    Sakshi Mehta
# 7     Harsh Gupta
# 8     Amit Sharma
# 9      Neha Verma
# Name: CustomerName, dtype: object

# %% [markdown]
# # 11. Unique values (Category)

# %%
final_df["CustomerName"].nunique()
# Out:
# 8

# %%
unique_name = final_df["CustomerName"].unique().tolist()

# %%
unique_name
# Out:
# ['Amit Sharma',
#  'Neha Verma',
#  'Rohit Kumar',
#  'Pooja Singh',
#  'Vikram Rana',
#  'Alok Jain',
#  'Sakshi Mehta',
#  'Harsh Gupta']

# %% [markdown]
# # 12. Count unique cities

# %%
final_df["City"].nunique()
# Out:
# 8

# %%
unique_cities = final_df["City"].unique().tolist()

# %%
unique_cities
# Out:
# ['Delhi',
#  'Mumbai',
#  'Kolkata',
#  'Jaipur',
#  'Chandigarh',
#  'Bangalore',
#  'Lucknow',
#  'Pune']

# %% [markdown]
# # 13. Missing values check

# %%
final_df.isnull().sum()
# Out:
# OrderID         0
# CustomerID_x    0
# OrderDate       0
# CustomerName    0
# Region          0
# City            0
# ProductID       0
# ProductName     0
# Category        0
# Sales           0
# Quantity        0
# UnitPrice       0
# dtype: int64

# %% [markdown]
# # 14. Data types

# %%
final_df.dtypes
# Out:
# OrderID                  int64
# CustomerID_x            object
# OrderDate       datetime64[ns]
# CustomerName            object
# Region                  object
# City                    object
# ProductID               object
# ProductName             object
# Category                object
# Sales                    int64
# Quantity                 int64
# UnitPrice                int64
# dtype: object

# %% [markdown]
# # 15. Convert OrderDate to datetime

# %%
df1["OrderDate"] = pd.to_datetime(df1["OrderDate"])

# %%
df1["OrderDate"]
# Out:
# 0    1900-01-03
# 1    2024-01-04
# 2    2024-01-05
# 3    2024-01-06
# 4    2024-01-07
# 5    2024-01-08
# 6    2024-01-09
# 7    2024-01-10
# 8    2024-01-11
# 9    2024-01-12
# 10   2024-01-13
# 11   2024-01-14
# 12   2024-01-15
# 13   2024-01-16
# 14   2024-01-17
# 15   2024-01-18
# 16   2024-01-19
# 17   2024-01-20
# 18   2024-01-21
# 19   2024-01-22
# 20   2024-01-23
# 21   2024-01-24
# 22   2024-01-25
# 23   2024-01-26
# 24   2024-01-27
# 25   2024-01-28
# 26   2024-01-29
# 27   2024-01-30
# 28   2024-01-31
# 29   2024-02-01
# 30   2024-02-02
# 31   2024-02-03
# 32   2024-02-04
# 33   2024-02-05
# 34   2024-02-06
# 35   2024-02-07
# 36   2024-02-08
# 37   2024-02-09
# 38   2024-02-10
# 39   2024-02-11
# 40   2024-02-12
# 41   2024-02-13
# 42   2024-02-14
# 43   2024-02-15
# 44   2024-02-16
# 45   2024-02-17
# 46   2024-02-18
# 47   2024-02-19
# 48   2024-02-20
# 49   2024-02-21
# Name: OrderDate, dtype: datetime64[ns]

# %% [markdown]
# # 16. Sales < 5000

# %%
final_df[final_df["Sales"] < 5000]
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 19     1025         C001 2024-01-27   Amit Sharma  North       Delhi
# 20     1033         C001 2024-02-04   Amit Sharma  North       Delhi
# 21     1019         C003 2024-01-21   Rohit Kumar   East     Kolkata
# 22     1044         C004 2024-02-15   Pooja Singh   West      Jaipur
# 23     1005         C005 2024-01-07   Vikram Rana  North  Chandigarh
# 24     1037         C005 2024-02-08   Vikram Rana  North  Chandigarh
# 25     1014         C006 2024-01-16     Alok Jain  South   Bangalore
# 26     1048         C008 2024-02-19   Harsh Gupta   West        Pune
# 35     1009         C001 2024-01-11   Amit Sharma  North       Delhi
# 36     1034         C002 2024-02-05    Neha Verma  South      Mumbai
# 37     1004         C004 2024-01-06   Pooja Singh   West      Jaipur
# 38     1028         C004 2024-01-30   Pooja Singh   West      Jaipur
# 39     1046         C006 2024-02-17     Alok Jain  South   Bangalore
# ...

# %%
final_df.count()
# Out:
# OrderID         50
# CustomerID_x    50
# OrderDate       50
# CustomerName    50
# Region          50
# City            50
# ProductID       50
# ProductName     50
# Category        50
# Sales           50
# Quantity        50
# UnitPrice       50
# dtype: int64

# %% [markdown]
# # 17. Filter: Region = 'North'

# %%
final_df[final_df["Region"]=="North"].count()
# Out:
# OrderID         13
# CustomerID_x    13
# OrderDate       13
# CustomerName    13
# Region          13
# City            13
# ProductID       13
# ProductName     13
# Category        13
# Sales           13
# Quantity        13
# UnitPrice       13
# dtype: int64

# %%
final_df[final_df["Region"]=="North"]
# Out:
#     OrderID CustomerID_x  OrderDate CustomerName Region        City ProductID  \
# 0      1001         C001 1900-01-03  Amit Sharma  North       Delhi      P101
# 5      1045         C005 2024-02-16  Vikram Rana  North  Chandigarh      P101
# 9      1041         C001 2024-02-12  Amit Sharma  North       Delhi      P102
# 14     1021         C005 2024-01-23  Vikram Rana  North  Chandigarh      P102
# 19     1025         C001 2024-01-27  Amit Sharma  North       Delhi      P103
# 20     1033         C001 2024-02-04  Amit Sharma  North       Delhi      P103
# 23     1005         C005 2024-01-07  Vikram Rana  North  Chandigarh      P103
# 24     1037         C005 2024-02-08  Vikram Rana  North  Chandigarh      P103
# 27     1017         C001 2024-01-19  Amit Sharma  North       Delhi      P201
# 28     1049         C001 2024-02-20  Amit Sharma  North       Delhi      P201
# 32     1029         C005 2024-01-31  Vikram Rana  North  Chandigarh      P201
# ...

# %% [markdown]
# # 18. Filter multiple conditions

# %%
final_df[(final_df['Region']=='North') & (final_df["Sales"]<10000)]
# Out:
#     OrderID CustomerID_x  OrderDate CustomerName Region        City ProductID  \
# 19     1025         C001 2024-01-27  Amit Sharma  North       Delhi      P103
# 20     1033         C001 2024-02-04  Amit Sharma  North       Delhi      P103
# 23     1005         C005 2024-01-07  Vikram Rana  North  Chandigarh      P103
# 24     1037         C005 2024-02-08  Vikram Rana  North  Chandigarh      P103
# 27     1017         C001 2024-01-19  Amit Sharma  North       Delhi      P201
# 28     1049         C001 2024-02-20  Amit Sharma  North       Delhi      P201
# 32     1029         C005 2024-01-31  Vikram Rana  North  Chandigarh      P201
# 35     1009         C001 2024-01-11  Amit Sharma  North       Delhi      P202
#
#    ProductName     Category  Sales  Quantity  UnitPrice
# 19  Headphones  Electronics   2800         2       2400
# 20  Headphones  Electronics   2750         3       2400
# 23  Headphones  Electronics   2500         2       2400
# ...

# %% [markdown]
# # 19. Sort by Sales

# %%
df1.sort_values("Sales")
# Out:
#     OrderID  OrderDate     month CustomerID  CustomerName Region ProductID  \
# 4      1005 2024-01-07   January       C005   Vikram Rana  North      P103
# 18     1019 2024-01-21   January       C003   Rohit Kumar   East      P103
# 13     1014 2024-01-16   January       C006     Alok Jain  South      P103
# 32     1033 2024-02-04  February       C001   Amit Sharma  North      P103
# 24     1025 2024-01-27   January       C001   Amit Sharma  North      P103
# 43     1044 2024-02-15  February       C004   Pooja Singh   West      P103
# 47     1048 2024-02-19  February       C008   Harsh Gupta   West      P103
# 36     1037 2024-02-08  February       C005   Vikram Rana  North      P103
# 14     1015 2024-01-17   January       C007  Sakshi Mehta   East      P202
# 38     1039 2024-02-10  February       C007  Sakshi Mehta   East      P202
# 3      1004 2024-01-06   January       C004   Pooja Singh   West      P202
# ...

# %% [markdown]
# # ****************************

# %%
df1["faltu"] = 0

# %%
df1
# Out:
#     OrderID  OrderDate     month CustomerID  CustomerName Region ProductID  \
# 0      1001 1900-01-03   January       2024   Amit Sharma  North      P101
# 1      1002 2024-01-04   January       C002    Neha Verma  South      P102
# 2      1003 2024-01-05   January       C003   Rohit Kumar   East      P201
# 3      1004 2024-01-06   January       C004   Pooja Singh   West      P202
# 4      1005 2024-01-07   January       C005   Vikram Rana  North      P103
# 5      1006 2024-01-08   January       C006     Alok Jain  South      P203
# 6      1007 2024-01-09   January       C007  Sakshi Mehta   East      P101
# 7      1008 2024-01-10   January       C008   Harsh Gupta   West      P102
# 8      1009 2024-01-11   January       C001   Amit Sharma  North      P202
# 9      1010 2024-01-12   January       C002    Neha Verma  South      P201
# 10     1011 2024-01-13   January       C003   Rohit Kumar   East      P102
# ...

# %%
df1=df1.drop(columns=["faltu"])

# %%
df1
# Out:
#     OrderID  OrderDate     month CustomerID  CustomerName Region ProductID  \
# 0      1001 1900-01-03   January       2024   Amit Sharma  North      P101
# 1      1002 2024-01-04   January       C002    Neha Verma  South      P102
# 2      1003 2024-01-05   January       C003   Rohit Kumar   East      P201
# 3      1004 2024-01-06   January       C004   Pooja Singh   West      P202
# 4      1005 2024-01-07   January       C005   Vikram Rana  North      P103
# 5      1006 2024-01-08   January       C006     Alok Jain  South      P203
# 6      1007 2024-01-09   January       C007  Sakshi Mehta   East      P101
# 7      1008 2024-01-10   January       C008   Harsh Gupta   West      P102
# 8      1009 2024-01-11   January       C001   Amit Sharma  North      P202
# 9      1010 2024-01-12   January       C002    Neha Verma  South      P201
# 10     1011 2024-01-13   January       C003   Rohit Kumar   East      P102
# ...

# %%
df1=df1.drop(columns=['NewColumn'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df1=df1.drop(columns=['NewColumn'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %% [markdown]
# ## 2nd method = del df["ColumnName"]

# %%
df1

# %%
final_df.head(1)
# Out:
#    OrderID CustomerID_x  OrderDate CustomerName Region   City ProductID  \
# 0     1001         C001 1900-01-03  Amit Sharma  North  Delhi      P101
#
#   ProductName     Category  Sales  Quantity  UnitPrice
# 0      Laptop  Electronics  55000         1      55000

# %% [markdown]
# # 20. Sort by Profit Desc

# %%
final_df.loc[:, "Profit"]=final_df["Sales"] - final_df["UnitPrice"]

# %%
final_df.head(5)
# Out:
#    OrderID CustomerID_x  OrderDate CustomerName Region     City ProductID  \
# 0     1001         C001 1900-01-03  Amit Sharma  North    Delhi      P101
# 1     1018         C002 2024-01-20   Neha Verma  South   Mumbai      P101
# 2     1042         C002 2024-02-13   Neha Verma  South   Mumbai      P101
# 3     1027         C003 2024-01-29  Rohit Kumar   East  Kolkata      P101
# 4     1012         C004 2024-01-14  Pooja Singh   West   Jaipur      P101
#
#   ProductName     Category  Sales  Quantity  UnitPrice  Profit
# 0      Laptop  Electronics  55000         1      55000       0
# 1      Laptop  Electronics  62000         1      55000    7000
# 2      Laptop  Electronics  64000         1      55000    9000
# 3      Laptop  Electronics  61000         1      55000    6000
# 4      Laptop  Electronics  60000         1      55000    5000

# %%
final_df.sort_values("Profit")
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# 15     1031         C007 2024-02-02  Sakshi Mehta   East     Lucknow
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 23     1005         C005 2024-01-07   Vikram Rana  North  Chandigarh
# 21     1019         C003 2024-01-21   Rohit Kumar   East     Kolkata
# 25     1014         C006 2024-01-16     Alok Jain  South   Bangalore
# 20     1033         C001 2024-02-04   Amit Sharma  North       Delhi
# 19     1025         C001 2024-01-27   Amit Sharma  North       Delhi
# 22     1044         C004 2024-02-15   Pooja Singh   West      Jaipur
# 46     1006         C006 2024-01-08     Alok Jain  South   Bangalore
# 30     1003         C003 2024-01-05   Rohit Kumar   East     Kolkata
# 26     1048         C008 2024-02-19   Harsh Gupta   West        Pune
# ...

# %% [markdown]
# # ***************

# %%
final_df["SalesLevel"] = final_df["Sales"].apply(lambda x: "High" if x > 10000 else "Low")

# %% [markdown]
# ### method 2 = *df["Category"] = np.where(df["Sales"] > 10000, "High", "Low")*

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %%
final_df=final_df.drop(columns=["vineet"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 final_df=final_df.drop(columns=["vineet"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %%
final_df.sort_values("Profit", ascending=False)
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 38     1028         C004 2024-01-30   Pooja Singh   West      Jaipur
# 35     1009         C001 2024-01-11   Amit Sharma  North       Delhi
# 36     1034         C002 2024-02-05    Neha Verma  South      Mumbai
# 39     1046         C006 2024-02-17     Alok Jain  South   Bangalore
# 37     1004         C004 2024-01-06   Pooja Singh   West      Jaipur
# ...

# %% [markdown]
# # 21. Top 10 sales orders

# %%
df1.nlargest(10, 'Sales')
# Out:
#     OrderID  OrderDate     month CustomerID  CustomerName Region ProductID  \
# 41     1042 2024-02-13  February       C002    Neha Verma  South      P101
# 21     1022 2024-01-24   January       C006     Alok Jain  South      P101
# 17     1018 2024-01-20   January       C002    Neha Verma  South      P101
# 26     1027 2024-01-29   January       C003   Rohit Kumar   East      P101
# 31     1032 2024-02-03  February       C008   Harsh Gupta   West      P101
# 11     1012 2024-01-14   January       C004   Pooja Singh   West      P101
# 44     1045 2024-02-16  February       C005   Vikram Rana  North      P101
# 6      1007 2024-01-09   January       C007  Sakshi Mehta   East      P101
# 0      1001 1900-01-03   January       2024   Amit Sharma  North      P101
# 25     1026 2024-01-28   January       C002    Neha Verma  South      P102
#
#    ProductName     Category  Sales  Quantity
# 41      Laptop  Electronics  64000         1
# 21      Laptop  Electronics  63000         1
# ...

# %% [markdown]
# # 22. Bottom 10 profitability

# %%
final_df["Profit"] = pd.to_numeric(final_df["Profit"], errors="coerce")

# %% [markdown]
# #### errors="coerce" ka matlab:
#
# #### valid number → numeric
#
# #### string ("No Profit", "zzzzzzzzz", etc.) → NaN

# %%
final_df.nsmallest(10,'Profit')
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# 15     1031         C007 2024-02-02  Sakshi Mehta   East     Lucknow
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 23     1005         C005 2024-01-07   Vikram Rana  North  Chandigarh
# 21     1019         C003 2024-01-21   Rohit Kumar   East     Kolkata
# 25     1014         C006 2024-01-16     Alok Jain  South   Bangalore
# 20     1033         C001 2024-02-04   Amit Sharma  North       Delhi
# 19     1025         C001 2024-01-27   Amit Sharma  North       Delhi
# 22     1044         C004 2024-02-15   Pooja Singh   West      Jaipur
#
#    ProductID ProductName     Category  Sales  Quantity  UnitPrice  Profit  \
# 12      P102      Mobile  Electronics  17500         2      18000    -500
# ...

# %% [markdown]
# # 23. Find duplicated rows

# %%
final_df[final_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID_x, OrderDate, CustomerName, Region, City, ProductID, ProductName, Category, Sales, Quantity, UnitPrice, Profit, SalesLevel]
# Index: []

# %% [markdown]
# # 24. Drop duplicates

# %%
df1.drop_duplicates(inplace=True)

# %% [markdown]
# # 25. Fill missing profits with 0

# %% [markdown]
# ### no missing values for 25th task

# %%
final_df["Profit"]=final_df["Profit"].replace(0,"no-profit")

# %% [markdown]
# ### *final_df["Profit_Status"] = final_df["Profit"].apply(lambda x: "No Profit" if x == 0 else "Profit")*

# %%
final_df.head(5)
# Out:
#    OrderID CustomerID_x  OrderDate CustomerName Region     City ProductID  \
# 0     1001         C001 1900-01-03  Amit Sharma  North    Delhi      P101
# 1     1018         C002 2024-01-20   Neha Verma  South   Mumbai      P101
# 2     1042         C002 2024-02-13   Neha Verma  South   Mumbai      P101
# 3     1027         C003 2024-01-29  Rohit Kumar   East  Kolkata      P101
# 4     1012         C004 2024-01-14  Pooja Singh   West   Jaipur      P101
#
#   ProductName     Category  Sales  Quantity  UnitPrice     Profit SalesLevel
# 0      Laptop  Electronics  55000         1      55000  no-profit       High
# 1      Laptop  Electronics  62000         1      55000       7000       High
# 2      Laptop  Electronics  64000         1      55000       9000       High
# 3      Laptop  Electronics  61000         1      55000       6000       High
# 4      Laptop  Electronics  60000         1      55000       5000       High

# %%
final_df["Profit"]=final_df["Profit"].replace("no-profit",0)

# %%
final_df.head(5)
# Out:
#    OrderID CustomerID_x  OrderDate CustomerName Region     City ProductID  \
# 0     1001         C001 1900-01-03  Amit Sharma  North    Delhi      P101
# 1     1018         C002 2024-01-20   Neha Verma  South   Mumbai      P101
# 2     1042         C002 2024-02-13   Neha Verma  South   Mumbai      P101
# 3     1027         C003 2024-01-29  Rohit Kumar   East  Kolkata      P101
# 4     1012         C004 2024-01-14  Pooja Singh   West   Jaipur      P101
#
#   ProductName     Category  Sales  Quantity  UnitPrice  Profit SalesLevel
# 0      Laptop  Electronics  55000         1      55000       0       High
# 1      Laptop  Electronics  62000         1      55000    7000       High
# 2      Laptop  Electronics  64000         1      55000    9000       High
# 3      Laptop  Electronics  61000         1      55000    6000       High
# 4      Laptop  Electronics  60000         1      55000    5000       High

# %% [markdown]
# # 26. Replace negative profit with 0

# %%
final_df['newprofit']=final_df['Sales']-final_df['UnitPrice']

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %%
final_df["Profit"] = final_df["Sales"].astype(float) - final_df["UnitPrice"].astype(float)

# %%
final_df.nsmallest(10,"newprofit")
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# 15     1031         C007 2024-02-02  Sakshi Mehta   East     Lucknow
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 23     1005         C005 2024-01-07   Vikram Rana  North  Chandigarh
# 21     1019         C003 2024-01-21   Rohit Kumar   East     Kolkata
# 25     1014         C006 2024-01-16     Alok Jain  South   Bangalore
# 20     1033         C001 2024-02-04   Amit Sharma  North       Delhi
# 19     1025         C001 2024-01-27   Amit Sharma  North       Delhi
# 22     1044         C004 2024-02-15   Pooja Singh   West      Jaipur
#
#    ProductID ProductName     Category  Sales  Quantity  UnitPrice  Profit  \
# 12      P102      Mobile  Electronics  17500         2      18000  -500.0
# ...

# %%
del final_df["newprofit"]

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %%
final_df.nsmallest(10,['Profit'])
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# 15     1031         C007 2024-02-02  Sakshi Mehta   East     Lucknow
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 23     1005         C005 2024-01-07   Vikram Rana  North  Chandigarh
# 21     1019         C003 2024-01-21   Rohit Kumar   East     Kolkata
# 25     1014         C006 2024-01-16     Alok Jain  South   Bangalore
# 20     1033         C001 2024-02-04   Amit Sharma  North       Delhi
# 19     1025         C001 2024-01-27   Amit Sharma  North       Delhi
# 22     1044         C004 2024-02-15   Pooja Singh   West      Jaipur
#
#    ProductID ProductName     Category  Sales  Quantity  UnitPrice  Profit  \
# 12      P102      Mobile  Electronics  17500         2      18000  -500.0
# ...

# %% [markdown]
# # 27. Remove rows with Quantity = 0

# %%
final_df = final_df[final_df['Quantity'] > 0]

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 28. Remove outliers in Sales (> 99th percentile)

# %% [markdown]
# # 29. Create a Discount column (5%)

# %%
final_df['Discount'] = final_df['Sales'] * 0.05

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %%
final_df['ProfitPercentage'] = final_df['Profit']/final_df['UnitPrice'] * 100

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %%
final_df["ProfitPercentage"] = final_df["ProfitPercentage"].round(1)

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 30. Calculate Net Sales

# %%
final_df['NetSales'] = final_df['Sales'] - final_df['Discount']

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 31. Total sales per region

# %%
final_df.groupby('Region')['Sales'].sum()
# Out:
# Region
# East     239450
# North    204500
# South    298550
# West     217700
# Name: Sales, dtype: int64

# %% [markdown]
# # 32. Average profit per category

# %%
final_df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Electronics    2109.259259
# Furniture      1328.260870
# Name: Profit, dtype: float64

# %% [markdown]
# # 33. Quantity sold per product

# %%
final_df.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False)
# Out:
# ProductName
# Headphones    19
# Chair         17
# Mobile        14
# Laptop         9
# Bed            8
# Table          8
# Name: Quantity, dtype: int64

# %% [markdown]
# # 34. Highest selling product

# %%
final_df.groupby('ProductName')['Sales'].sum().nlargest(1)
# Out:
# ProductName
# Laptop    542500
# Name: Sales, dtype: int64

# %% [markdown]
# # 35. Customer-wise sales summary

# %%
final_df.groupby('CustomerName')['Sales'].sum().sort_values(ascending=False)
# Out:
# CustomerName
# Neha Verma      190850
# Harsh Gupta     124100
# Rohit Kumar     122800
# Sakshi Mehta    116650
# Alok Jain       107700
# Vikram Rana     106650
# Amit Sharma      97850
# Pooja Singh      93600
# Name: Sales, dtype: int64

# %% [markdown]
# # 36. Region-wise order count

# %%
final_df.groupby('Region')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Region
# North    20
# West     19
# East     18
# South    18
# Name: Quantity, dtype: int64

# %% [markdown]
# # 37. Sales & Profit per region

# %%
final_df.groupby('Region')[['Sales','Profit']].sum()
# Out:
#          Sales   Profit
# Region
# East    239450  16550.0
# North   204500  13400.0
# South   298550  35650.0
# West    217700  21900.0

# %%
final_df.groupby('Region')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
# Out:
#          Sales   Profit
# Region
# South   298550  35650.0
# East    239450  16550.0
# West    217700  21900.0
# North   204500  13400.0

# %% [markdown]
# # 38. Category × Region matrix

# %%
final_df.pivot_table(values='Sales', index='Category', columns='Region', aggfunc='sum')
# Out:
# Region         East   North   South    West
# Category
# Electronics  194000  163700  229700  163750
# Furniture     45450   40800   68850   53950

# %% [markdown]
# # 39. Monthly sales

# %%
final_df.groupby(final_df['OrderDate'].dt.month)['Sales'].sum()
# Out:
# OrderDate
# 1    594350
# 2    365850
# Name: Sales, dtype: int64

# %%
final_df['Month'] = final_df['OrderDate'].dt.month
final_df.groupby('Month')['Sales'].sum()
# Out:
# Month
# 1    594350
# 2    365850
# Name: Sales, dtype: int64

# %%
final_df['MonthName'] = final_df['OrderDate'].dt.month_name()
final_df.groupby('MonthName')['Sales'].sum()
# Out:
# MonthName
# February    365850
# January     594350
# Name: Sales, dtype: int64

# %%
final_df.groupby(final_df["OrderDate"].dt.month_name())["Sales"].sum()
# Out:
# OrderDate
# February    365850
# January     594350
# Name: Sales, dtype: int64

# %%
final_df.groupby([final_df["OrderDate"].dt.year,
                  final_df["OrderDate"].dt.month])["Sales"].sum()
# Out:
# OrderDate  OrderDate
# 1900       1             55000
# 2024       1            539350
#            2            365850
# Name: Sales, dtype: int64

# %% [markdown]
# # 40. Yearly sales

# %%
final_df.groupby(final_df['OrderDate'].dt.year)['Sales'].sum()
# Out:
# OrderDate
# 1900     55000
# 2024    905200
# Name: Sales, dtype: int64

# %% [markdown]
# # 41. Average unit price per category

# %%
final_df.groupby('Category')['UnitPrice'].mean()
# Out:
# Category
# Electronics    25711.111111
# Furniture       7760.869565
# Name: UnitPrice, dtype: float64

# %% [markdown]
# # 42. Most profitable customer

# %%
final_df.groupby('CustomerName')['Profit'].sum().nlargest(1)
# Out:
# CustomerName
# Neha Verma    22350.0
# Name: Profit, dtype: float64

# %% [markdown]
# # 43. City-wise average quantity

# %%
final_df.groupby('City')['Quantity'].mean()
# Out:
# City
# Bangalore     1.500000
# Chandigarh    1.500000
# Delhi         1.571429
# Jaipur        1.833333
# Kolkata       1.333333
# Lucknow       1.666667
# Mumbai        1.285714
# Pune          1.333333
# Name: Quantity, dtype: float64

# %% [markdown]
# # 44. Number of unique products per category

# %%
final_df.groupby('Category')['ProductName'].nunique()
# Out:
# Category
# Electronics    3
# Furniture      3
# Name: ProductName, dtype: int64

# %% [markdown]
# # 45. Order count by month & region

# %%
final_df.groupby([final_df['OrderDate'].dt.month , 'Region'])['Quantity'].sum()
# Out:
# OrderDate  Region
# 1          East      10
#            North     12
#            South     10
#            West      11
# 2          East       8
#            North      8
#            South      8
#            West       8
# Name: Quantity, dtype: int64

# %%
final_df.pivot_table(values="OrderID" , index=final_df['OrderDate'].dt.month_name(), columns='Region' , aggfunc= 'count')
# Out:
# Region     East  North  South  West
# OrderDate
# February      5      5      6     5
# January       7      8      7     7

# %% [markdown]
# # 46. % Contribution of each region

# %%
final_df.groupby('Region')['Sales'].sum() / final_df['Sales'].sum() * 100
# Out:
# Region
# East     24.937513
# North    21.297646
# South    31.092481
# West     22.672360
# Name: Sales, dtype: float64

# %%
final_df.groupby('Region')['Sales'].sum()
# Out:
# Region
# East     239450
# North    204500
# South    298550
# West     217700
# Name: Sales, dtype: int64

# %% [markdown]
# # 47. Top 5 cities by sales

# %%
final_df.groupby('City')['Sales'].sum().nlargest(5)
# Out:
# City
# Mumbai       190850
# Pune         124100
# Kolkata      122800
# Lucknow      116650
# Bangalore    107700
# Name: Sales, dtype: int64

# %% [markdown]
# # 48. Category-wise profit ratio (profit / sales)

# %%
final_df.groupby('Category')['Profit'].sum()    /    final_df.groupby('Category')['Sales'].sum()
# Out:
# Category
# Electronics    0.075817
# Furniture      0.146137
# dtype: float64

# %% [markdown]
# # 49. Identify category with highest loss

# %%
final_df.groupby('Category')['Profit'].sum().nsmallest(1)
# Out:
# Category
# Furniture    30550.0
# Name: Profit, dtype: float64

# %% [markdown]
# # 50. Total orders per customer

# %%
final_df.groupby('CustomerName')['OrderID'].count()
# Out:
# CustomerName
# Alok Jain       6
# Amit Sharma     7
# Harsh Gupta     6
# Neha Verma      7
# Pooja Singh     6
# Rohit Kumar     6
# Sakshi Mehta    6
# Vikram Rana     6
# Name: OrderID, dtype: int64

# %%
final_df.groupby('CustomerName')['Quantity'].count()
# Out:
# CustomerName
# Alok Jain       6
# Amit Sharma     7
# Harsh Gupta     6
# Neha Verma      7
# Pooja Singh     6
# Rohit Kumar     6
# Sakshi Mehta    6
# Vikram Rana     6
# Name: Quantity, dtype: int64

# %% [markdown]
# # 51. Add column: Profit Margin (%)

# %%
final_df['ProfitMargin'] = ((final_df['Profit'] / final_df['Sales']) * 100).round(1)

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 52. Categorize profit into High/Medium/Low

# %%
final_df['ProfitLevel'] = pd.cut(final_df['Profit'], bins=[-9999,100,500,999999], labels=['Low','Medium','High'])

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %%
final_df['ProfitLevel'] = pd.cut(final_df['ProfitPercentage'], bins=[-100,10,15,100], labels=['Low','Medium','High'])

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 53. Running total of sales

# %%
final_df['RunningSales'] = final_df['Sales'].cumsum()

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 54. Top product per region

# %%
final_df.groupby(['Region','ProductName'])['Sales'].sum().groupby(level=0).nlargest(1)
# Out:
# Region  Region  ProductName
# East    East    Laptop         119000
# North   North   Laptop         114000
# South   South   Laptop         189000
# West    West    Laptop         120500
# Name: Sales, dtype: int64

# %% [markdown]
# # 55. Rank customers by sales

# %%
final_df['Rank'] = final_df['Sales'].rank(ascending=False)

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 56. Rolling 7-day sales

# %%
final_df['7DaySales'] = final_df['Sales'].rolling(7).sum()

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 57. Correlation matrix

# %%
final_df.corr()
# Out:
# ------------------------------------------------
# ValueError     Traceback (most recent call last)
# Cell In[315], line 1
# ----> 1 final_df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
# ...

# %%
final_df.select_dtypes(include='number').corr()
# Out:
#                    OrderID     Sales  Quantity  UnitPrice    Profit  Discount  \
# OrderID           1.000000 -0.073244 -0.012869  -0.092041  0.112680 -0.073244
# Sales            -0.073244  1.000000 -0.483881   0.997548  0.779684  1.000000
# Quantity         -0.012869 -0.483881  1.000000  -0.495843 -0.259633 -0.483881
# UnitPrice        -0.092041  0.997548 -0.495843   1.000000  0.733950  0.997548
# Profit            0.112680  0.779684 -0.259633   0.733950  1.000000  0.779684
# Discount         -0.073244  1.000000 -0.483881   0.997548  0.779684  1.000000
# ProfitPercentage  0.039393 -0.326295  0.550461  -0.363503  0.085659 -0.326295
# NetSales         -0.073244  1.000000 -0.483881   0.997548  0.779684  1.000000
# Month             0.855039 -0.075150  0.028944  -0.082603  0.009742 -0.075150
# ProfitMargin      0.098661 -0.332997  0.548916  -0.375201  0.125275 -0.332997
# RunningSales      0.123465 -0.841953  0.236451  -0.845033 -0.610429 -0.841953
# ...

# %% [markdown]
# # 58. Average sales per weekday

# %%
final_df.groupby(final_df['OrderDate'].dt.day_name())['Sales'].mean()
# Out:
# OrderDate
# Friday       16085.714286
# Monday       19021.428571
# Saturday     21892.857143
# Sunday       17450.000000
# Thursday     11114.285714
# Tuesday      24864.285714
# Wednesday    23400.000000
# Name: Sales, dtype: float64

# %% [markdown]
# # 59. Most common product

# %%
final_df['ProductName'].mode()
# Out:
# 0    Mobile
# Name: ProductName, dtype: object

# %% [markdown]
# # 60. Most profitable month

# %%
final_df.groupby(final_df['OrderDate'].dt.month_name())['Profit'].sum().nlargest(1)
# Out:
# OrderDate
# January    50250.0
# Name: Profit, dtype: float64

# %% [markdown]
# # 61. Create a category-level summary DataFrame

# %%
summary = final_df.groupby('Category').agg({
'Sales':'sum',
'Profit':'sum',
'Quantity':'sum'
})

# %%
summary
# Out:
#               Sales   Profit  Quantity
# Category
# Electronics  751150  56950.0        42
# Furniture    209050  30550.0        33

# %% [markdown]
# # 62. Detect outliers in Profit

# %%
limit = final_df['Profit'].quantile(0.99)
final_df[final_df['Profit'] > limit]
# Out:
#    OrderID CustomerID_x  OrderDate CustomerName Region    City ProductID  \
# 2     1042         C002 2024-02-13   Neha Verma  South  Mumbai      P101
#
#   ProductName     Category  Sales  ...  Discount  ProfitPercentage  NetSales  \
# 2      Laptop  Electronics  64000  ...    3200.0              16.4   60800.0
#
#   Month  MonthName  ProfitMargin  ProfitLevel  RunningSales Rank  7DaySales
# 2     2   February          14.1         High        181000  1.0        NaN
#
# [1 rows x 24 columns]

# %% [markdown]
# # 63. Create a copy of dataset

# %%
df2 = df2.copy()

# %% [markdown]
# # 64. Extract Year, Month, Day columns

# %%
final_df['Year'] = final_df['OrderDate'].dt.year
final_df['Month'] = final_df['OrderDate'].dt.month
final_df['Day'] = final_df['OrderDate'].dt.day

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# ### 65. Merge with another file (dummy)
# ### merged = df.merge(product_info, on='ProductID')

# %% [markdown]
# # 66. Count orders per weekday

# %%
final_df['OrderDate'].dt.day_name().value_counts()
# Out:
# OrderDate
# Wednesday    8
# Saturday     7
# Tuesday      7
# Monday       7
# Sunday       7
# Friday       7
# Thursday     7
# Name: count, dtype: int64

# %% [markdown]
# # 67. Dataset overview in one line

# %%
final_df.describe(include='all')
# Out:
#            OrderID CustomerID_x            OrderDate CustomerName Region  \
# count     50.00000           50                   50           50     50
# unique         NaN            8                  NaN            8      4
# top            NaN         C001                  NaN  Amit Sharma  North
# freq           NaN            7                  NaN            7     13
# mean    1025.50000          NaN  2021-08-04 16:48:00          NaN    NaN
# min     1001.00000          NaN  1900-01-03 00:00:00          NaN    NaN
# 25%     1013.25000          NaN  2024-01-15 06:00:00          NaN    NaN
# 50%     1025.50000          NaN  2024-01-27 12:00:00          NaN    NaN
# 75%     1037.75000          NaN  2024-02-08 18:00:00          NaN    NaN
# max     1050.00000          NaN  2024-02-21 00:00:00          NaN    NaN
# std       14.57738          NaN                  NaN          NaN    NaN
#
#          City ProductID ProductName     Category         Sales  ...  \
# ...

# %% [markdown]
# # 68. Top customer per city

# %%
final_df.groupby(['City','CustomerName'])['Sales'].sum().groupby(level=0).nlargest(1)
# Out:
# City        City        CustomerName
# Bangalore   Bangalore   Alok Jain       107700
# Chandigarh  Chandigarh  Vikram Rana     106650
# Delhi       Delhi       Amit Sharma      97850
# Jaipur      Jaipur      Pooja Singh      93600
# Kolkata     Kolkata     Rohit Kumar     122800
# Lucknow     Lucknow     Sakshi Mehta    116650
# Mumbai      Mumbai      Neha Verma      190850
# Pune        Pune        Harsh Gupta     124100
# Name: Sales, dtype: int64

# %% [markdown]
# # 69. Quantity × Price = Total Value

# %%
final_df['TotalValue'] = final_df['Quantity'] * final_df['UnitPrice']

# %%
final_df
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region        City  \
# 0      1001         C001 1900-01-03   Amit Sharma  North       Delhi
# 1      1018         C002 2024-01-20    Neha Verma  South      Mumbai
# 2      1042         C002 2024-02-13    Neha Verma  South      Mumbai
# 3      1027         C003 2024-01-29   Rohit Kumar   East     Kolkata
# 4      1012         C004 2024-01-14   Pooja Singh   West      Jaipur
# 5      1045         C005 2024-02-16   Vikram Rana  North  Chandigarh
# 6      1022         C006 2024-01-24     Alok Jain  South   Bangalore
# 7      1007         C007 2024-01-09  Sakshi Mehta   East     Lucknow
# 8      1032         C008 2024-02-03   Harsh Gupta   West        Pune
# 9      1041         C001 2024-02-12   Amit Sharma  North       Delhi
# 10     1002         C002 2024-01-04    Neha Verma  South      Mumbai
# 11     1026         C002 2024-01-28    Neha Verma  South      Mumbai
# 12     1011         C003 2024-01-13   Rohit Kumar   East     Kolkata
# ...

# %% [markdown]
# # 70. Detect negative profits

# %%
final_df[final_df['Profit'] < 0]
# Out:
#     OrderID CustomerID_x  OrderDate  CustomerName Region     City ProductID  \
# 12     1011         C003 2024-01-13   Rohit Kumar   East  Kolkata      P102
# 15     1031         C007 2024-02-02  Sakshi Mehta   East  Lucknow      P102
#
#    ProductName     Category  Sales  ...  Month  MonthName  ProfitMargin  \
# 12      Mobile  Electronics  17500  ...      1    January          -2.9
# 15      Mobile  Electronics  17600  ...      2   February          -2.3
#
#    ProfitLevel  RunningSales  Rank  7DaySales  Year Day  TotalValue
# 12         Low        617200  19.0   256200.0  2024  13       36000
# 15         Low        673100  18.0   130600.0  2024   2       36000
#
# [2 rows x 27 columns]

# %% [markdown]
# # 76. Bar chart: Region-wise sales

# %%
final_df.groupby('Region')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# # 77. Category-wise profit chart

# %%
final_df.groupby('Category')['Profit'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# # 78. Line chart: Monthly sales

# %%
final_df.groupby(final_df['OrderDate'].dt.month)['Sales'].sum().plot()
# Out:
# <Axes: xlabel='OrderDate'>

# %% [markdown]
# # 79. Scatter plot: Sales vs Profit

# %%
final_df.plot.scatter('Sales','Profit')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# # 80. Histogram of Sales

# %%
final_df['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # 81. Pie chart of region contribution

# %%
final_df.groupby('Region')['Sales'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='Sales'>

# %%
final_df.groupby('Region')['Sales'].sum().plot(
    kind='pie',
    autopct='%1.1f%%',      # 1 decimal percentage
    figsize=(6,6)
)
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# # 82. Boxplot: Profit

# %%
final_df.boxplot(column='Profit')
# Out:
# <Axes: >

# %% [markdown]
# # 83. Heatmap (correlation)

# %%
sns.heatmap(final_df.select_dtypes(include='number').corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 84. City-wise sales bar chart

# %%
final_df.groupby('City')['Sales'].sum().nlargest(10).plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# # 85. Product-wise quantity chart

# %%
final_df.groupby('ProductName')['Quantity'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='ProductName'>

# %% [markdown]
# # 86. Running sales trend

# %%
final_df['RunningSales'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # 87. Scatter: Quantity vs Sales

# %%
final_df.plot.scatter('Quantity','Sales')
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %% [markdown]
# # 88. Profit margin distribution

# %%
final_df['ProfitMargin'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # 89. Sales vs Unit Price

# %%
final_df.plot.scatter('UnitPrice', 'Sales')
# Out:
# <Axes: xlabel='UnitPrice', ylabel='Sales'>

# %% [markdown]
# # 90. Category-wise average unit price

# %%
final_df.groupby('Category')['UnitPrice'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>
